# %%
import pandas as pd
import pandas as pd
from pandas import DataFrame
from pandasql import sqldf, load_meat, load_births
df = pd.read_excel("/Users/rampantisme/Downloads/2019sbnqssfxzjggwylymd.xlsx")

# %%
df
# Out:
#     2019年上半年全省司法行政机关公开考试录用公务员拟录用人员名单（第一批） Unnamed: 1       Unnamed: 2  \
# 0                                     NaN        NaN              NaN
# 1                                    市（州）       招录单位           招录\n职位
# 2                                     NaN        NaN              NaN
# 3                                     自贡市     大安区司法局            司法助理员
# 4                                     NaN     大安区司法局            司法助理员
# 5                                     NaN     沿滩区司法局            司法助理员
# 6                                     NaN     沿滩区司法局            司法助理员
# 7                                     NaN     沿滩区司法局            司法助理员
# 8                                     NaN     沿滩区司法局            司法助理员
# 9                                     NaN     沿滩区司法局            司法助理员
# 10                                    NaN      荣县司法局  司法助理员（31020153）
# 11                                    NaN      荣县司法局              NaN
# ...

# %%
pysqldf = lambda sql: sqldf(sql, globals())
sql = "select * from df where Unnamed: 1 ='大安区司法局'"
print pysqldf(sql)
# Out:
#   File "<ipython-input-26-2d18ec1ab679>", line 3
#     print pysqldf(sql)
#                 ^
# SyntaxError: invalid syntax
